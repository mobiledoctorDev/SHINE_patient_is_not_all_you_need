# %% [markdown]
# # Import library

# %%
import os
import os, sys
import glob
import re
import datetime
from datetime import datetime, timedelta 
import math, copy, time
from itertools import cycle
from collections import defaultdict

from parse import parse
import numpy as np
import pandas as pd

import torch
from torch import nn, optim
from torch.autograd import Variable
from torch.utils.data import Dataset
from torch.utils.data import DataLoader
import torch.nn.functional as F

# import torchvision
# import torchvision.transforms as transforms

from sklearn.metrics import roc_auc_score, plot_roc_curve
from sklearn import svm


from tqdm.notebook import tqdm

import matplotlib.pyplot as plt
import seaborn

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
pd.set_option("display.max_column", 100)

# %%
# Util functions
def size_and_ratio(df, col, dropna=True):
    if pd.__version__ > '1.1':
        sr = df.groupby(col, dropna=dropna).size().sort_values(ascending=False)
    elif dropna:
        sr = df.groupby(col).size().sort_values(ascending=False)
    else:  # dropna == False
        sr = df.fillna('nan').groupby(col).size().sort_values(ascending=False)
    sr_ratio = sr.copy() / sum(sr)
    print("Sum :", sum(sr), sr.shape)
    sr.name = 'size'
    sr_ratio.name = 'ratio'
    return pd.concat([sr, sr_ratio], axis=1)

# %%
dir_result = "../mc_scripts/model/train_result/"

all_results = dict()
result_dirs = sorted(os.listdir(dir_result))
display(result_dirs)
for train_name in result_dirs:
    
    if not os.path.isdir(os.path.join(dir_result, train_name)):
        continue
    
    if not 'v12' in train_name:
        continue
        
    df_result = pd.read_csv(os.path.join(dir_result, train_name, "result.csv"))
    print(train_name)
    display(df_result)
    all_results[train_name] = df_result
# Out:
# ['.DS_Store',
#  'all_manual_20230323_014415',
#  'owid_manual_20230321_050601',
#  'patient+loc+loc-1+loc-2+loc-3+loc-4+loc-5+loc-6+loc-7_manual_20230323_010929',
#  'patient+loc_manual_20230323_002327',
#  'patient_manual_20230321_050609',
#  'patient_manual_20230322_212408',
#  'si3_manual_20230321_050605',
#  'v10_patient_testmonthvalrandom_20230327_012748',
#  'v10_patient_testmonthvalrandom_20230327_012810',
#  'v10_patient_testmonthvalrandom_20230327_013715',
#  'v10_patient_testmonthvalrandom_20230327_014846',
#  'v10_patient_testmonthvalrandom_20230327_022118',
#  'v10_patient_testmonthvalrandom_20230327_023343',
#  'v10_patient_testmonthvalrandom_20230327_024558',
#  'v10_patient_testmonthvalrandom_20230327_050747',
#  'v10_patient_testmonthvalrandom_20230327_052517',
#  'v10_patient_testmonthvalrandom_20230327_071354',
#  'v10_patient_testmonthvalrandom_20230327_084910',
#  'v10_patient_testmonthvalrandom_20230327_122900',
#  'v11_all_testmonthvalrandom_20230327_180822_2022-03',
#  'v11_all_testmonthvalrandom_20230327_180848_2022-04',
#  'v11_all_testmonthvalrandom_20230327_182339_2022-05',
#  'v11_all_testmonthvalrandom_20230327_184324_2022-06',
#  'v11_all_testmonthvalrandom_20230327_190411_2022-07',
#  'v11_all_testmonthvalrandom_20230327_192320_2022-08',
#  'v11_all_testmonthvalrandom_20230327_194302_2022-09',
#  'v11_all_testmonthvalrandom_20230327_200415_2022-10',
#  'v11_all_testmonthvalrandom_20230327_202735_2022-11',
#  'v11_all_testmonthvalrandom_20230327_204924_2022-12',
#  'v11_all_testmonthvalrandom_20230327_211425_2023-01',
#  'v11_all_testmonthvalrandom_20230327_213946_2023-02',
#  'v11_patient_testmonthvalrandom_20230327_140012_2022-03',
#  'v11_patient_testmonthvalrandom_20230327_140026_2022-04',
#  'v11_patient_testmonthvalrandom_20230327_140901_2022-05',
#  'v11_patient_testmonthvalrandom_20230327_141951_2022-06',
#  'v11_patient_testmonthvalrandom_20230327_143500_2022-07',
#  'v11_patient_testmonthvalrandom_20230327_144857_2022-08',
#  'v11_patient_testmonthvalrandom_20230327_150211_2022-09',
#  'v11_patient_testmonthvalrandom_20230327_151740_2022-10',
#  'v11_patient_testmonthvalrandom_20230327_153615_2022-11',
#  'v11_patient_testmonthvalrandom_20230327_155243_2022-12',
#  'v11_patient_testmonthvalrandom_20230327_171931_2023-01',
#  'v11_patient_testmonthvalrandom_20230327_174401_2023-02',
#  'v11_si3_testmonthvalrandom_20230331_041051_2022-03',
#  'v11_si3_testmonthvalrandom_20230331_041111_2022-04',
#  'v11_si3_testmonthvalrandom_20230331_042229_2022-05',
#  'v11_si3_testmonthvalrandom_20230331_043859_2022-06',
#  'v11_si3_testmonthvalrandom_20230331_045254_2022-07',
#  'v11_si3_testmonthvalrandom_20230331_050501_2022-08',
#  'v11_si3_testmonthvalrandom_20230331_051703_2022-09',
#  'v11_si3_testmonthvalrandom_20230331_053523_2022-10',
#  'v11_si3_testmonthvalrandom_20230331_055144_2022-11',
#  'v11_si3_testmonthvalrandom_20230331_060447_2022-12',
#  'v11_si3_testmonthvalrandom_20230331_061936_2023-01',
#  'v11_si3_testmonthvalrandom_20230331_063344_2023-02',
#  'v11_si6_testmonthvalrandom_20230328_200928_2022-03',
#  'v11_si6_testmonthvalrandom_20230328_200949_2022-04',
#  'v11_si6_testmonthvalrandom_20230328_202323_2022-05',
#  'v11_si6_testmonthvalrandom_20230328_203625_2022-06',
#  'v11_si6_testmonthvalrandom_20230328_205919_2022-07',
#  'v11_si6_testmonthvalrandom_20230328_211731_2022-08',
#  'v11_si6_testmonthvalrandom_20230328_213859_2022-09',
#  'v11_si6_testmonthvalrandom_20230328_220209_2022-10',
#  'v11_si6_testmonthvalrandom_20230328_222258_2022-11',
#  'v11_si6_testmonthvalrandom_20230328_224301_2022-12',
#  'v11_si6_testmonthvalrandom_20230328_230421_2023-01',
#  'v11_si6_testmonthvalrandom_20230328_232706_2023-02',
#  'v12_all_testmonthvalmonth_20230409_232347_2022-03',
#  'v12_all_testmonthvalmonth_20230409_232421_2022-04',
#  'v12_all_testmonthvalmonth_20230409_232702_2022-05',
#  'v12_patient_testmonthvalmonth_20230409_232347_2022-03',
#  'v12_patient_testmonthvalmonth_20230409_232414_2022-04',
#  'v12_patient_testmonthvalmonth_20230409_232556_2022-05',
#  'v5_all_manual_20230323_020113',
#  'v5_patient+loc+loc-1+loc-2+loc-3+loc-4+loc-5+loc-6+loc-7_manual_20230323_020203',
#  'v6_all_manual_20230323_235916',
#  'v6_patient+loc+loc-1+loc-2+loc-3+loc-4+loc-5+loc-6+loc-7_manual_20230323_235913',
#  'v6_patient+owid_manual_20230323_132517',
#  'v6_patient+si3_manual_20230323_132622',
#  'v6_patient_manual_20230323_132347',
#  'v7_all_manual_20230324_225725',
#  'v7_patient+loc_manual_20230324_225725',
#  'v7_patient+owid_manual_20230324_225725',
#  'v7_patient+si3_manual_20230324_225725',
#  'v7_patient_manual_20230324_225725',
#  'v8_all_manual_20230325_020028',
#  'v8_patient+loc_manual_20230325_020028',
#  'v8_patient+owid_manual_20230325_020028',
#  'v8_patient+si3_manual_20230325_020028',
#  'v8_patient_manual_20230325_020028',
#  'v9_all_manual_20230325_193621',
#  'v9_patient+loc_manual_20230325_150837',
#  'v9_patient+owid_manual_20230325_135044',
#  'v9_patient+si6_manual_20230325_140830',
#  'v9_patient_manual_20230325_133728']
# v12_all_testmonthvalmonth_20230409_232347_2022-03
#   Unnamed: 0         0         1         2         3         4      mean  \
# 0         LR  0.814730  0.807111  0.815724  0.822610  0.824736  0.816982
# 1    XGBoost  0.806862  0.806862  0.806862  0.806862  0.806862  0.806862
# 2       LGBM  0.753670  0.753670  0.753670  0.753670  0.753670  0.753670
# 3     TabNet  0.557580  0.442585  0.355408  0.606015  0.558014  0.503920
#
#             std
# 0  5.714005e-03
# 1  1.110223e-16
# 2  0.000000e+00
# 3  8.371262e-02
# v12_all_testmonthvalmonth_20230409_232421_2022-04
#   Unnamed: 0         0         1         2         3         4      mean  \
# 0         LR  0.896917  0.895778  0.897901  0.896794  0.897625  0.897003
# 1    XGBoost  0.720680  0.720680  0.720680  0.720680  0.720680  0.720680
# 2       LGBM  0.856246  0.856246  0.856246  0.856246  0.856246  0.856246
# 3     TabNet  0.615321  0.473130  0.371254  0.498219  0.541369  0.499859
#
#         std
# 0  0.000676
# 1  0.000000
# 2  0.000000
# 3  0.073384
# v12_all_testmonthvalmonth_20230409_232702_2022-05
#   Unnamed: 0         0         1         2         3         4      mean  \
# 0         LR  0.802829  0.797840  0.797853  0.791113  0.801489  0.798225
# 1    XGBoost  0.761836  0.761836  0.761836  0.761836  0.761836  0.761836
# 2       LGBM  0.796301  0.796301  0.796301  0.796301  0.796301  0.796301
#
#         std
# 0  0.003713
# 1  0.000000
# 2  0.000000
# v12_patient_testmonthvalmonth_20230409_232347_2022-03
#   Unnamed: 0         0         1         2         3         4      mean  \
# 0         LR  0.835584  0.836962  0.832525  0.836475  0.836525  0.835614
# 1    XGBoost  0.776877  0.776877  0.776877  0.776877  0.776877  0.776877
# 2       LGBM  0.747755  0.747755  0.747755  0.747755  0.747755  0.747755
# 3     TabNet  0.488531  0.590363  0.419127  0.732859  0.781013  0.602379
#
#             std
# 0  1.468022e-03
# 1  1.110223e-16
# 2  0.000000e+00
# 3  1.262418e-01
# v12_patient_testmonthvalmonth_20230409_232414_2022-04
#   Unnamed: 0         0         1         2         3         4      mean  \
# 0         LR  0.867363  0.867499  0.867827  0.867721  0.868394  0.867761
# 1    XGBoost  0.829915  0.829915  0.829915  0.829915  0.829915  0.829915
# 2       LGBM  0.837509  0.837509  0.837509  0.837509  0.837509  0.837509
# 3     TabNet  0.507875  0.593993  0.413360  0.735524  0.795008  0.609152
#
#         std
# 0  0.000325
# 1  0.000000
# 2  0.000000
# 3  0.128669
# v12_patient_testmonthvalmonth_20230409_232556_2022-05
#   Unnamed: 0         0         1         2         3         4      mean  \
# 0         LR  0.774129  0.773187  0.772722  0.771687  0.772669  0.772879
# 1    XGBoost  0.782641  0.782641  0.782641  0.782641  0.782641  0.782641
# 2       LGBM  0.781453  0.781453  0.781453  0.781453  0.781453  0.781453
#
#         std
# 0  0.000724
# 1  0.000000
# 2  0.000000

# %% [markdown]
# # 비교... t-test

# %%
v3_12_performance = {
    'RL': [0.8418617324532305, 0.8415487608796515, 0.8416251735299258, 0.8412595824666369, 0.8419745211855217, 0.8416539541029933, 0.0002503429729046297],
    'XGBoost': [0.8397734250529169, 0.8399769252098603, 0.8401759641491977, 0.8404991164501336, 0.8403203245753149, 0.8401491510874848, 0.00025429387104055484],
    'LGBM': [0.8551935665124077, 0.8584086173336836, 0.8574014116665187, 0.8546029699355114, 0.8569555186863247, 0.8565124168268892, 0.0014119193339345117],
    'TabNet': [0.8465492138648236, 0.8526912809963112, 0.8462506554558175, 0.8456920881335273, 0.8485493264247758, 0.847946512975051, 0.002560742725296901]
}

# Print the dictionary
print(v3_12_performance)

v3_1_performance = {
    'RL': [0.838625043318763, 0.8381056968241842, 0.838121731946367, 0.8381724699449158, 0.8386626181573107, 0.8383375120383081, 0.0002513588908400427],
    'XGBoost': [0.8304989459898792, 0.8283381534431956, 0.8300372780691224, 0.8290787606908792, 0.8294619283119947, 0.8294830133010143, 0.0007501863108692136],
    'LGBM': [0.8472786243684077, 0.8440041088205618, 0.8467651414632839, 0.8452445571530047, 0.8453708038239218, 0.8457326471258361, 0.0011673129195661717],
    'TabNet': [0.8299095954171143, 0.8266923994478175, 0.8363573898458905, 0.8356437072436631, 0.8373971598208662, 0.8332000503550703, 0.0041649152103427145]
}

# Print the dictionary
print(v3_1_performance)
# Out:
# {'RL': [0.8418617324532305, 0.8415487608796515, 0.8416251735299258, 0.8412595824666369, 0.8419745211855217, 0.8416539541029933, 0.0002503429729046297], 'XGBoost': [0.8397734250529169, 0.8399769252098603, 0.8401759641491977, 0.8404991164501336, 0.8403203245753149, 0.8401491510874848, 0.00025429387104055484], 'LGBM': [0.8551935665124077, 0.8584086173336836, 0.8574014116665187, 0.8546029699355114, 0.8569555186863247, 0.8565124168268892, 0.0014119193339345117], 'TabNet': [0.8465492138648236, 0.8526912809963112, 0.8462506554558175, 0.8456920881335273, 0.8485493264247758, 0.847946512975051, 0.002560742725296901]}
# {'RL': [0.838625043318763, 0.8381056968241842, 0.838121731946367, 0.8381724699449158, 0.8386626181573107, 0.8383375120383081, 0.0002513588908400427], 'XGBoost': [0.8304989459898792, 0.8283381534431956, 0.8300372780691224, 0.8290787606908792, 0.8294619283119947, 0.8294830133010143, 0.0007501863108692136], 'LGBM': [0.8472786243684077, 0.8440041088205618, 0.8467651414632839, 0.8452445571530047, 0.8453708038239218, 0.8457326471258361, 0.0011673129195661717], 'TabNet': [0.8299095954171143, 0.8266923994478175, 0.8363573898458905, 0.8356437072436631, 0.8373971598208662, 0.8332000503550703, 0.0041649152103427145]}

# %%
for key, values in v3_12_performance.items():

    v3_12_values = values
    v3_1_values = v3_1_performance[key]
    
    # Perform the paired t-test
    stat, p = ttest_rel(v3_12_values, v3_1_values)

    # Print the results
    print(f"{key}, Paired t-test:")
    print(f" - Statistic: {stat:.4f}")
    print(f" - p-value: {p:.4f}")
    print()
# Out:
# RL, Paired t-test:
#  - Statistic: 5.9632
#  - p-value: 0.0010
#
# XGBoost, Paired t-test:
#  - Statistic: 5.5913
#  - p-value: 0.0014
#
# LGBM, Paired t-test:
#  - Statistic: 5.5061
#  - p-value: 0.0015
#
# TabNet, Paired t-test:
#  - Statistic: 3.9345
#  - p-value: 0.0077

# %%
# Define the dictionary of values
RL_values = {0: 0.838625043318763, 1: 0.8381056968241842, 2: 0.838121731946367, 3: 0.8381724699449158, 4: 0.8386626181573107}

# Assign the values to a list variable
RL_list = [RL_values[i] for i in range(len(RL_values))]

# Print the list variable
print(RL_list)
# Out:
# [0.838625043318763, 0.8381056968241842, 0.838121731946367, 0.8381724699449158, 0.8386626181573107]

# %%
from scipy.stats import ttest_rel

# Define the RL performance in the first table and the second table as lists
v3_12_RL = [0.8418617324532305, 0.8415487608796515, 0.8416251735299258, 0.8412595824666369, 0.8419745211855217]
v3_1_RL = [0.838625043318763, 0.8381056968241842, 0.838121731946367, 0.8381724699449158, 0.8386626181573107]

# Perform the paired t-test
stat, p = ttest_rel(table1_RL, table2_RL)

# Print the results
print("Paired t-test:")
print(f"Statistic: {stat:.4f}")
print(f"p-value: {p:.4f}")
# Out:
# Paired t-test:
# Statistic: 6.9994
# p-value: 0.0022
